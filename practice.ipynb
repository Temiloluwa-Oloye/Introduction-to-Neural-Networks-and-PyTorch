# %% [markdown]
# # Preparation #

# %%
import torch
from torch.utils.data import Dataset
torch.manual_seed(0)

# %% [markdown]
# # Create a Simple Dataset #

# %%
class MyDataset(Dataset):
    def __init__(self, length=100, transform=None):
        super(MyDataset, self).__init__()
        self.length = length
        self.transform = transform
        self.x = 2 * torch.ones(length, 2)
        self.y = torch.ones(length, 1)

    def __getitem__(self, index):
        sample = self.x[index], self.y[index]
        if self.transform:
            sample = self.transform(sample)
        return sample

    
    def __len__(self):
        return self.length

# %%
dataset = MyDataset()

# %%
dataset[1]
# Out:
# (tensor([2., 2.]), tensor([1.]))

# %%
len(dataset)
# Out:
# 100

# %% [markdown]
# # Apply Transformations #

# %%
class add_mult:
    def __init__(self, addx = 1, muly = 2):
        self.addx = addx
        self.muly = muly

    def __call__(self, sample):
        x = sample[0]
        y = sample[1]
        x = x + self.addx
        y = y * self.muly
        sample = x , y
        return sample

# %%
mytransform = add_mult()
dataset2 = MyDataset(transform= mytransform)

# %%
dataset2[1]
# Out:
# (tensor([3., 3.]), tensor([2.]))

# %% [markdown]
# # Use torchvision.transforms #

# %%
from torchvision import transforms

# %% [markdown]
# # Compose Multiple Transforms #

# %%
data_transform = transforms.Compose([add_mult(), add_mult()])

# %%
Dataset3 = MyDataset(transform=data_transform)

# %%
Dataset3[1]
# Out:
# (tensor([4., 4.]), tensor([4.]))
