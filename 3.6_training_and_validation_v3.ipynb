# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# <h1>Linear regression: Training and Validation Data</h1>

# %% [markdown]
# <h2>Objective</h2><ul><li> How to use learning rate hyperparameter to improve your model result.  .</li></ul>

# %% [markdown]
# <h2>Table of Contents</h2>
# <p>In this lab, you will learn to select the best learning rate by using validation data.</p>
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
# <font size="3">
#         1. <a href="#Make-Some-Data">Make Some Data</a><br>
#         2. <a href="#Create-a-Linear-Regression-Object-Data-Loader-and-Criterion-Function">Create a Linear Regression Object Data Loader and Criterion Function</a><br>
#         3. <a href="#Different-learning-rates-and-Data-Structures-to-Store-results-for-Different-Hyperparameters">Different learning rates and Data Structures to Store results for Different Hyperparameters</a><br>
#         4. <a href="#Train-different-modules-for-different-Hyperparameters">Train different modules for different Hyperparameters</a><br>
#         5. <a href="#View-Results">View Results</a><br>
#
# <p>Estimated Time Needed: <strong>30 min</strong></p>
# </font>
# </div>

# %% [markdown]
# <h2>Preparation</h2>

# %% [markdown]
# We'll need the following libraries and set the random seed.

# %%
# Import libraries we need for this lab, and set the random seed

import torch
import numpy as np
import matplotlib.pyplot as plt
from torch import nn, optim

torch.manual_seed(1)

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <!-- <h2 id="Makeup_Data">Make Some Data</h2> -->
# ## Make Some Data

# %% [markdown]
# First, we'll create some artificial data in a dataset class. The class will include the option to produce training data or validation data. The training data will include outliers.

# %%
# Create Data class

from torch.utils.data import Dataset, DataLoader

class Data(Dataset):
    
    # Constructor
    def __init__(self, train = True):
            self.x = torch.arange(-3, 3, 0.1).view(-1, 1)
            self.f = -3 * self.x + 1
            self.y = self.f + 0.1 * torch.randn(self.x.size())
            self.len = self.x.shape[0]
            
            #outliers 
            if train == True:
                self.y[0] = 0
                self.y[50:55] = 20
            else:
                pass
      
    # Getter
    def __getitem__(self, index):    
        return self.x[index], self.y[index]
    
    # Get Length
    def __len__(self):
        return self.len

# %% [markdown]
# Create two objects: one that contains training data and a second that contains validation data. Assume that the training data has the outliers.

# %%
# Create training dataset and validation dataset

train_data = Data()
val_data = Data(train = False)

# %% [markdown]
# Overlay the training points in red over the function that generated the data. Notice the outliers at x=-3 and around x=2:

# %%
# Plot out training points

plt.plot(train_data.x.numpy(), train_data.y.numpy(), 'xr',label="training data ")
plt.plot(train_data.x.numpy(), train_data.f.numpy(),label="true function  ")
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <!-- <h2 id="LR_Loader_Cost">Create a Linear Regression Object,  Data Loader, and Criterion Function</h2> -->
# ## Create a Linear Regression Object Data Loader and Criterion Function

# %%
# Create Linear Regression Class

from torch import nn

class linear_regression(nn.Module):
    
    # Constructor
    def __init__(self, input_size, output_size):
        super(linear_regression, self).__init__()
        self.linear = nn.Linear(input_size, output_size)
    
    # Prediction function
    def forward(self, x):
        yhat = self.linear(x)
        return yhat

# %% [markdown]
# Create the criterion function and a <code>DataLoader</code> object:

# %%
# Create MSELoss function and DataLoader

criterion = nn.MSELoss()
trainloader = DataLoader(dataset = train_data, batch_size = 1)

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <!-- <h2 id="LR_Hyper">Different learning rates and Data Structures to Store results for different Hyperparameters</h2> -->
# ## Different learning rates and Data Structures to Store results for Different Hyperparameters

# %% [markdown]
# Create a list with different learning rates and a tensor (can be a list) for the training and validating cost/total loss. Include the list MODELS, which stores the training model for every value of the learning rate.

# %%
# Create Learning Rate list, the error lists and the MODELS list

learning_rates=[0.0001, 0.001, 0.01, 0.1]

train_error=torch.zeros(len(learning_rates))
validation_error=torch.zeros(len(learning_rates))

MODELS=[]

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <!-- <h2 id="Model">Train different models  for different Hyperparameters</h2> -->
# ## Train different modules for different Hyperparameters

# %% [markdown]
# Try different values of learning rates, perform stochastic gradient descent, and save the results on the training data and validation data. Finally, save each model in a list.

# %%
# Define the train model function and train the model

def train_model_with_lr (iter, lr_list):
    
    # iterate through different learning rates 
    for i, lr in enumerate(lr_list):
        model = linear_regression(1, 1)
        optimizer = optim.SGD(model.parameters(), lr = lr)
        for epoch in range(iter):
            for x, y in trainloader:
                yhat = model(x)
                loss = criterion(yhat, y)
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                
        # train data
        Yhat = model(train_data.x)
        train_loss = criterion(Yhat, train_data.y)
        train_error[i] = train_loss.item()
    
        # validation data
        Yhat = model(val_data.x)
        val_loss = criterion(Yhat, val_data.y)
        validation_error[i] = val_loss.item()
        MODELS.append(model)

train_model_with_lr(10, learning_rates)

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <!-- <h2 id="Result">View the Results</h2>
#  -->
# ## View Results

# %% [markdown]
# Plot the training loss and validation loss for each learning rate:

# %%
# Plot the training loss and validation loss

plt.semilogx(np.array(learning_rates), train_error.numpy(), label = 'training loss/total Loss')
plt.semilogx(np.array(learning_rates), validation_error.numpy(), label = 'validation cost/total Loss')
plt.ylabel('Cost\ Total Loss')
plt.xlabel('learning rate')
plt.legend()
plt.show()

# %% [markdown]
# Produce a prediction by using the validation data for each model:

# %%
# Plot the predictions

i = 0
for model, learning_rate in zip(MODELS, learning_rates):
    yhat = model(val_data.x)
    plt.plot(val_data.x.numpy(), yhat.detach().numpy(), label = 'lr:' + str(learning_rate))
    print(i, yhat.detach().numpy()[0:3])
    i+=1
plt.plot(val_data.x.numpy(), val_data.f.numpy(), 'or', label = 'validation data')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# 0 [[1.7119563]
#  [1.6655214]
#  [1.619086 ]]
# 1 [[5.855464]
#  [5.741811]
#  [5.628157]]
# 2 [[6.5968227]
#  [6.4620833]
#  [6.3273435]]
# 3 [[14.248304]
#  [13.820604]
#  [13.392902]]

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h3>Practice</h3>

# %% [markdown]
# The object <code>good_model</code> is the best performing model. Use the train loader to get the data samples x and y. Produce an estimate for <code>yhat</code> and print it out for every sample in a for a loop. Compare it to the actual prediction <code>y</code>.

# %%
good_model = MODELS[np.argmin(validation_error)]

#Type your code here: 
i = 1
for x, y in trainloader:
    yhat = good_model(x)
    print("Predicted Value for sample " + str(i) + ": ", yhat)
    print("Actual value for sample " + str(i) + ": ", y)
    print("\n")
    i+=1
# Out:
# Predicted Value for sample 1:  tensor([[14.2483]], grad_fn=<AddmmBackward0>)
# Actual value for sample 1:  tensor([[0.]])
#
#
# Predicted Value for sample 2:  tensor([[13.8206]], grad_fn=<AddmmBackward0>)
# Actual value for sample 2:  tensor([[9.6250]])
#
#
# Predicted Value for sample 3:  tensor([[13.3929]], grad_fn=<AddmmBackward0>)
# Actual value for sample 3:  tensor([[9.3346]])
#
#
# Predicted Value for sample 4:  tensor([[12.9652]], grad_fn=<AddmmBackward0>)
# Actual value for sample 4:  tensor([[8.9391]])
#
#
# Predicted Value for sample 5:  tensor([[12.5375]], grad_fn=<AddmmBackward0>)
# Actual value for sample 5:  tensor([[8.7900]])
#
#
# Predicted Value for sample 6:  tensor([[12.1098]], grad_fn=<AddmmBackward0>)
# Actual value for sample 6:  tensor([[8.4391]])
#
#
# Predicted Value for sample 7:  tensor([[11.6821]], grad_fn=<AddmmBackward0>)
# Actual value for sample 7:  tensor([[8.1020]])
#
#
# Predicted Value for sample 8:  tensor([[11.2544]], grad_fn=<AddmmBackward0>)
# Actual value for sample 8:  tensor([[7.7391]])
#
#
# Predicted Value for sample 9:  tensor([[10.8267]], grad_fn=<AddmmBackward0>)
# Actual value for sample 9:  tensor([[7.5288]])
#
#
# Predicted Value for sample 10:  tensor([[10.3990]], grad_fn=<AddmmBackward0>)
# Actual value for sample 10:  tensor([[7.3304]])
#
#
# Predicted Value for sample 11:  tensor([[9.9713]], grad_fn=<AddmmBackward0>)
# Actual value for sample 11:  tensor([[6.9223]])
#
#
# Predicted Value for sample 12:  tensor([[9.5436]], grad_fn=<AddmmBackward0>)
# Actual value for sample 12:  tensor([[6.6749]])
#
#
# Predicted Value for sample 13:  tensor([[9.1159]], grad_fn=<AddmmBackward0>)
# Actual value for sample 13:  tensor([[6.3778]])
#
#
# Predicted Value for sample 14:  tensor([[8.6882]], grad_fn=<AddmmBackward0>)
# Actual value for sample 14:  tensor([[6.2687]])
#
#
# Predicted Value for sample 15:  tensor([[8.2605]], grad_fn=<AddmmBackward0>)
# Actual value for sample 15:  tensor([[5.8228]])
#
#
# Predicted Value for sample 16:  tensor([[7.8328]], grad_fn=<AddmmBackward0>)
# Actual value for sample 16:  tensor([[5.5468]])
#
#
# Predicted Value for sample 17:  tensor([[7.4051]], grad_fn=<AddmmBackward0>)
# Actual value for sample 17:  tensor([[5.1303]])
#
#
# Predicted Value for sample 18:  tensor([[6.9774]], grad_fn=<AddmmBackward0>)
# Actual value for sample 18:  tensor([[4.7839]])
#
#
# Predicted Value for sample 19:  tensor([[6.5497]], grad_fn=<AddmmBackward0>)
# Actual value for sample 19:  tensor([[4.6700]])
#
#
# Predicted Value for sample 20:  tensor([[6.1220]], grad_fn=<AddmmBackward0>)
# Actual value for sample 20:  tensor([[4.3199]])
#
#
# Predicted Value for sample 21:  tensor([[5.6943]], grad_fn=<AddmmBackward0>)
# Actual value for sample 21:  tensor([[4.0866]])
#
#
# Predicted Value for sample 22:  tensor([[5.2666]], grad_fn=<AddmmBackward0>)
# Actual value for sample 22:  tensor([[3.7244]])
#
#
# Predicted Value for sample 23:  tensor([[4.8389]], grad_fn=<AddmmBackward0>)
# Actual value for sample 23:  tensor([[3.3337]])
#
#
# Predicted Value for sample 24:  tensor([[4.4112]], grad_fn=<AddmmBackward0>)
# Actual value for sample 24:  tensor([[3.1807]])
#
#
# Predicted Value for sample 25:  tensor([[3.9835]], grad_fn=<AddmmBackward0>)
# Actual value for sample 25:  tensor([[2.9102]])
#
#
# Predicted Value for sample 26:  tensor([[3.5558]], grad_fn=<AddmmBackward0>)
# Actual value for sample 26:  tensor([[2.4824]])
#
#
# Predicted Value for sample 27:  tensor([[3.1281]], grad_fn=<AddmmBackward0>)
# Actual value for sample 27:  tensor([[1.9754]])
#
#
# Predicted Value for sample 28:  tensor([[2.7004]], grad_fn=<AddmmBackward0>)
# Actual value for sample 28:  tensor([[1.7554]])
#
#
# Predicted Value for sample 29:  tensor([[2.2727]], grad_fn=<AddmmBackward0>)
# Actual value for sample 29:  tensor([[1.6061]])
#
#
# Predicted Value for sample 30:  tensor([[1.8450]], grad_fn=<AddmmBackward0>)
# Actual value for sample 30:  tensor([[1.2382]])
#
#
# Predicted Value for sample 31:  tensor([[1.4173]], grad_fn=<AddmmBackward0>)
# Actual value for sample 31:  tensor([[0.9202]])
#
#
# Predicted Value for sample 32:  tensor([[0.9896]], grad_fn=<AddmmBackward0>)
# Actual value for sample 32:  tensor([[0.6868]])
#
#
# Predicted Value for sample 33:  tensor([[0.5619]], grad_fn=<AddmmBackward0>)
# Actual value for sample 33:  tensor([[0.5879]])
#
#
# Predicted Value for sample 34:  tensor([[0.1342]], grad_fn=<AddmmBackward0>)
# Actual value for sample 34:  tensor([[0.0928]])
#
#
# Predicted Value for sample 35:  tensor([[-0.2935]], grad_fn=<AddmmBackward0>)
# Actual value for sample 35:  tensor([[-0.1842]])
#
#
# Predicted Value for sample 36:  tensor([[-0.7213]], grad_fn=<AddmmBackward0>)
# Actual value for sample 36:  tensor([[-0.5773]])
#
#
# Predicted Value for sample 37:  tensor([[-1.1490]], grad_fn=<AddmmBackward0>)
# Actual value for sample 37:  tensor([[-0.7801]])
#
#
# Predicted Value for sample 38:  tensor([[-1.5767]], grad_fn=<AddmmBackward0>)
# Actual value for sample 38:  tensor([[-1.0954]])
#
#
# Predicted Value for sample 39:  tensor([[-2.0044]], grad_fn=<AddmmBackward0>)
# Actual value for sample 39:  tensor([[-1.3847]])
#
#
# Predicted Value for sample 40:  tensor([[-2.4321]], grad_fn=<AddmmBackward0>)
# Actual value for sample 40:  tensor([[-1.7476]])
#
#
# Predicted Value for sample 41:  tensor([[-2.8598]], grad_fn=<AddmmBackward0>)
# Actual value for sample 41:  tensor([[-2.0111]])
#
#
# Predicted Value for sample 42:  tensor([[-3.2875]], grad_fn=<AddmmBackward0>)
# Actual value for sample 42:  tensor([[-2.2707]])
#
#
# Predicted Value for sample 43:  tensor([[-3.7152]], grad_fn=<AddmmBackward0>)
# Actual value for sample 43:  tensor([[-2.6158]])
#
#
# Predicted Value for sample 44:  tensor([[-4.1429]], grad_fn=<AddmmBackward0>)
# Actual value for sample 44:  tensor([[-2.9029]])
#
#
# Predicted Value for sample 45:  tensor([[-4.5706]], grad_fn=<AddmmBackward0>)
# Actual value for sample 45:  tensor([[-3.1547]])
#
#
# Predicted Value for sample 46:  tensor([[-4.9983]], grad_fn=<AddmmBackward0>)
# Actual value for sample 46:  tensor([[-3.3858]])
#
#
# Predicted Value for sample 47:  tensor([[-5.4260]], grad_fn=<AddmmBackward0>)
# Actual value for sample 47:  tensor([[-3.7751]])
#
#
# Predicted Value for sample 48:  tensor([[-5.8537]], grad_fn=<AddmmBackward0>)
# Actual value for sample 48:  tensor([[-4.2775]])
#
#
# Predicted Value for sample 49:  tensor([[-6.2814]], grad_fn=<AddmmBackward0>)
# Actual value for sample 49:  tensor([[-4.4025]])
#
#
# Predicted Value for sample 50:  tensor([[-6.7091]], grad_fn=<AddmmBackward0>)
# Actual value for sample 50:  tensor([[-4.8023]])
#
#
# Predicted Value for sample 51:  tensor([[-7.1368]], grad_fn=<AddmmBackward0>)
# Actual value for sample 51:  tensor([[20.]])
#
#
# Predicted Value for sample 52:  tensor([[-7.5645]], grad_fn=<AddmmBackward0>)
# Actual value for sample 52:  tensor([[20.]])
#
#
# Predicted Value for sample 53:  tensor([[-7.9922]], grad_fn=<AddmmBackward0>)
# Actual value for sample 53:  tensor([[20.]])
#
#
# Predicted Value for sample 54:  tensor([[-8.4199]], grad_fn=<AddmmBackward0>)
# Actual value for sample 54:  tensor([[20.]])
#
#
# Predicted Value for sample 55:  tensor([[-8.8476]], grad_fn=<AddmmBackward0>)
# Actual value for sample 55:  tensor([[20.]])
#
#
# Predicted Value for sample 56:  tensor([[-9.2753]], grad_fn=<AddmmBackward0>)
# Actual value for sample 56:  tensor([[-6.3390]])
#
#
# Predicted Value for sample 57:  tensor([[-9.7030]], grad_fn=<AddmmBackward0>)
# Actual value for sample 57:  tensor([[-6.8704]])
#
#
# Predicted Value for sample 58:  tensor([[-10.1307]], grad_fn=<AddmmBackward0>)
# Actual value for sample 58:  tensor([[-7.1185]])
#
#
# Predicted Value for sample 59:  tensor([[-10.5584]], grad_fn=<AddmmBackward0>)
# Actual value for sample 59:  tensor([[-7.4996]])
#
#
# Predicted Value for sample 60:  tensor([[-10.9861]], grad_fn=<AddmmBackward0>)
# Actual value for sample 60:  tensor([[-7.7831]])

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!--
# for x, y in trainloader:
#     print("yhat= ", model(x),"y", y)
# -->

# %% [markdown]
# <a href="https://dataplatform.cloud.ibm.com/registration/stepone?utm_source=skills_network&utm_content=in_lab_content_link&utm_id=Lab-IBMDeveloperSkillsNetwork-DL0110EN-SkillsNetwork&context=cpdaas&apps=data_science_experience%2Cwatson_machine_learning"><img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DL0110EN-SkillsNetwork/Template/module%201/images/Watson_Studio.png"></a>

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2>About the Authors:</h2>
#
# <a href="https://www.linkedin.com/in/joseph-s-50398b136/">Joseph Santarcangelo</a> has a PhD in Electrical Engineering, his research focused on using machine learning, signal processing, and computer vision to determine how videos impact human cognition. Joseph has been working for IBM since he completed his PhD.

# %% [markdown]
# Other contributors: <a href="https://www.linkedin.com/in/michelleccarey/">Michelle Carey</a>, <a href="https://www.linkedin.com/in/jiahui-mavis-zhou-a4537814a/">Mavis Zhou</a>

# %% [markdown]
# <!--
# ## Change Log
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2020-09-23  | 2.0  | Shubham  |  Migrated Lab to Markdown and added to course repo in GitLab |
#
# -->

# %% [markdown]
# <hr>

# %% [markdown]
# ## <h3 align="center"> &#169; IBM Corporation. All rights reserved. <h3/>
